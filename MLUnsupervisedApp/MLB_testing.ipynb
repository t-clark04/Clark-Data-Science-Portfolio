# %%
import pandas as pd
MLB_data = pd.read_csv("data/MLB_Pitchers.csv", encoding = 'latin-1')

# %%
MLB_data = (MLB_data.drop(columns = ["Lg", "Awards", "Player-additional"]).query('IP > 20').dropna())

# %%
MLB_data
# Out:
#       Rk             Player  Age Team  WAR   W   L   W-L%   ERA   G  ...  WP  \
# 0      1      Logan Gilbert   27  SEA  2.8   9  12  0.429  3.23  33  ...  11
# 1      2          Seth Lugo   34  KCR  5.4  16   9  0.640  3.00  33  ...   4
# 2      3         Logan Webb   27  SFG  3.6  13  10  0.565  3.47  33  ...   4
# 3      4       Zack Wheeler   34  PHI  6.1  16   7  0.696  2.57  32  ...   8
# 4      5         Aaron Nola   31  PHI  3.7  14   8  0.636  3.57  33  ...   2
# ..   ...                ...  ...  ...  ...  ..  ..    ...   ...  ..  ...  ..
# 719  536  Emmanuel RamÃ­rez   29  MIA -0.3   0   1  0.000  6.97  15  ...   2
# 720  537    Erasmo RamÃ­rez   34  TBR -0.2   3   0  1.000  4.35  13  ...   2
# 721  538         Ryder Ryan   29  PIT -0.2   1   0  1.000  5.66  15  ...   0
# 722  539      Scott Blewett   28  MIN  0.8   1   1  0.500  1.77  12  ...   0
# 724  541         River Ryan   25  LAD  0.7   1   0  1.000  1.33   4  ...   0
#
#       BF   ERA+   FIP   WHIP   H9  HR9  BB9   SO9  SO/BB
# 0    803  113.0  3.27  0.887  6.4  1.1  1.6   9.5   5.95
# 1    836  139.0  3.25  1.089  7.7  0.7  2.1   7.9   3.77
# 2    841  111.0  2.95  1.231  8.9  0.5  2.2   7.6   3.44
# 3    787  160.0  3.13  0.955  6.3  0.9  2.3  10.1   4.31
# 4    820  115.0  3.94  1.199  8.5  1.4  2.3   8.9   3.94
# ..   ...    ...   ...    ...  ...  ...  ...   ...    ...
# 719   92   65.0  4.62  1.403  9.1  1.3  3.5   9.1   2.63
# 720   85   93.0  6.46  1.065  5.2  2.2  4.4   6.5   1.50
# 721   93   75.0  4.52  1.452  9.1  0.9  3.9   7.4   1.89
# 722   85  240.0  4.00  1.230  7.5  0.9  3.5   8.0   2.25
# 724   81  296.0  3.36  1.180  6.6  0.4  4.0   8.0   2.00
#
# [642 rows x 35 columns]

# %%
duplicates = MLB_data[MLB_data.duplicated('Rk', keep = False)]

team_dict = dict()

for index, row in duplicates.iterrows():
    if row['Rk'] not in list(team_dict.keys()):
        team_dict[row['Rk']] = [row['Team']]
    else:
        team_dict[row['Rk']].append(row['Team'])

for elem in team_dict:
    del team_dict[elem][0]

# %%
team_df = pd.DataFrame(list(team_dict.items()), columns = ['Rk', 'Team'])

# %%
team_df
# Out:
#      Rk        Team
# 0    28  [CHW, STL]
# 1    30  [TOR, HOU]
# 2    54  [TBR, BAL]
# 3    58  [DET, LAD]
# 4    59  [TBR, MIL]
# ..  ...         ...
# 70  479       [WSN]
# 71  480       [SFG]
# 72  498       [CHW]
# 73  513       [TEX]
# 74  528       [MIL]
#
# [75 rows x 2 columns]

# %%
MLB_data_clean = MLB_data.groupby('Rk').agg("first").reset_index()

# %%
MLB_data_clean['Team'] = MLB_data_clean['Team'].apply(lambda x: [x])

# %%
MLB_data_clean
# Out:
#       Rk             Player  Age   Team  WAR   W   L   W-L%   ERA   G  ...  \
# 0      1      Logan Gilbert   27  [SEA]  2.8   9  12  0.429  3.23  33  ...
# 1      2          Seth Lugo   34  [KCR]  5.4  16   9  0.640  3.00  33  ...
# 2      3         Logan Webb   27  [SFG]  3.6  13  10  0.565  3.47  33  ...
# 3      4       Zack Wheeler   34  [PHI]  6.1  16   7  0.696  2.57  32  ...
# 4      5         Aaron Nola   31  [PHI]  3.7  14   8  0.636  3.57  33  ...
# ..   ...                ...  ...    ...  ...  ..  ..    ...   ...  ..  ...
# 530  536  Emmanuel RamÃ­rez   29  [MIA] -0.3   0   1  0.000  6.97  15  ...
# 531  537    Erasmo RamÃ­rez   34  [TBR] -0.2   3   0  1.000  4.35  13  ...
# 532  538         Ryder Ryan   29  [PIT] -0.2   1   0  1.000  5.66  15  ...
# 533  539      Scott Blewett   28  [MIN]  0.8   1   1  0.500  1.77  12  ...
# 534  541         River Ryan   25  [LAD]  0.7   1   0  1.000  1.33   4  ...
#
#      WP   BF   ERA+   FIP   WHIP   H9  HR9  BB9   SO9  SO/BB
# 0    11  803  113.0  3.27  0.887  6.4  1.1  1.6   9.5   5.95
# 1     4  836  139.0  3.25  1.089  7.7  0.7  2.1   7.9   3.77
# 2     4  841  111.0  2.95  1.231  8.9  0.5  2.2   7.6   3.44
# 3     8  787  160.0  3.13  0.955  6.3  0.9  2.3  10.1   4.31
# 4     2  820  115.0  3.94  1.199  8.5  1.4  2.3   8.9   3.94
# ..   ..  ...    ...   ...    ...  ...  ...  ...   ...    ...
# 530   2   92   65.0  4.62  1.403  9.1  1.3  3.5   9.1   2.63
# 531   2   85   93.0  6.46  1.065  5.2  2.2  4.4   6.5   1.50
# 532   0   93   75.0  4.52  1.452  9.1  0.9  3.9   7.4   1.89
# 533   0   85  240.0  4.00  1.230  7.5  0.9  3.5   8.0   2.25
# 534   0   81  296.0  3.36  1.180  6.6  0.4  4.0   8.0   2.00
#
# [535 rows x 35 columns]

# %%
MLB_data_clean.set_index('Rk', inplace = True)
team_df.set_index('Rk', inplace = True)

MLB_data_clean.update(team_df)

# %%
MLB_data_clean
# Out:
#                 Player  Age   Team  WAR   W   L   W-L%   ERA   G  GS  ...  WP  \
# Rk                                                                    ...
# 1        Logan Gilbert   27  [SEA]  2.8   9  12  0.429  3.23  33  33  ...  11
# 2            Seth Lugo   34  [KCR]  5.4  16   9  0.640  3.00  33  33  ...   4
# 3           Logan Webb   27  [SFG]  3.6  13  10  0.565  3.47  33  33  ...   4
# 4         Zack Wheeler   34  [PHI]  6.1  16   7  0.696  2.57  32  32  ...   8
# 5           Aaron Nola   31  [PHI]  3.7  14   8  0.636  3.57  33  33  ...   2
# ..                 ...  ...    ...  ...  ..  ..    ...   ...  ..  ..  ...  ..
# 536  Emmanuel RamÃ­rez   29  [MIA] -0.3   0   1  0.000  6.97  15   0  ...   2
# 537    Erasmo RamÃ­rez   34  [TBR] -0.2   3   0  1.000  4.35  13   0  ...   2
# 538         Ryder Ryan   29  [PIT] -0.2   1   0  1.000  5.66  15   0  ...   0
# 539      Scott Blewett   28  [MIN]  0.8   1   1  0.500  1.77  12   0  ...   0
# 541         River Ryan   25  [LAD]  0.7   1   0  1.000  1.33   4   4  ...   0
#
#       BF   ERA+   FIP   WHIP   H9  HR9  BB9   SO9  SO/BB
# Rk
# 1    803  113.0  3.27  0.887  6.4  1.1  1.6   9.5   5.95
# 2    836  139.0  3.25  1.089  7.7  0.7  2.1   7.9   3.77
# 3    841  111.0  2.95  1.231  8.9  0.5  2.2   7.6   3.44
# 4    787  160.0  3.13  0.955  6.3  0.9  2.3  10.1   4.31
# 5    820  115.0  3.94  1.199  8.5  1.4  2.3   8.9   3.94
# ..   ...    ...   ...    ...  ...  ...  ...   ...    ...
# 536   92   65.0  4.62  1.403  9.1  1.3  3.5   9.1   2.63
# 537   85   93.0  6.46  1.065  5.2  2.2  4.4   6.5   1.50
# 538   93   75.0  4.52  1.452  9.1  0.9  3.9   7.4   1.89
# 539   85  240.0  4.00  1.230  7.5  0.9  3.5   8.0   2.25
# 541   81  296.0  3.36  1.180  6.6  0.4  4.0   8.0   2.00
#
# [535 rows x 34 columns]

# %%
MLB_data_clean.columns
# Out:
# Index(['Player', 'Age', 'Team', 'Lg', 'WAR', 'W', 'L', 'W-L%', 'ERA', 'G',
#        'GS', 'GF', 'CG', 'SHO', 'SV', 'IP', 'H', 'R', 'ER', 'HR', 'BB', 'IBB',
#        'SO', 'HBP', 'BK', 'WP', 'BF', 'ERA+', 'FIP', 'WHIP', 'H9', 'HR9',
#        'BB9', 'SO9', 'SO/BB'],
#       dtype='object')

# %%
# Drop the unnecessary columns, restrict our scope only to pitchers with more 
# than 20 innings pitched, and drop any missing values.
MLB_data = (MLB_data.drop(columns = ["Lg", "Awards", "Player-additional"]).query('IP > 20').dropna())
duplicates = MLB_data[MLB_data.duplicated('Rk', keep = False)]
team_dict = dict()
for index, row in duplicates.iterrows():
    if row['Rk'] not in list(team_dict.keys()):
        team_dict[row['Rk']] = [row['Team']]
    else:
        team_dict[row['Rk']].append(row['Team'])
for elem in team_dict:
    del team_dict[elem][0]
team_df = pd.DataFrame(list(team_dict.items()), columns = ['Rk', 'Team'])
MLB_data_clean = MLB_data.groupby('Rk').agg("first").reset_index()
MLB_data_clean['Team'] = MLB_data_clean['Team'].apply(lambda x: [x])
MLB_data_clean.set_index('Rk', inplace = True)
team_df.set_index('Rk', inplace = True)
MLB_data_clean.update(team_df)

# %%
MLB_data_clean
# Out:
#                 Player  Age   Team  WAR   W   L   W-L%   ERA   G  GS  ...  WP  \
# Rk                                                                    ...
# 1        Logan Gilbert   27  [SEA]  2.8   9  12  0.429  3.23  33  33  ...  11
# 2            Seth Lugo   34  [KCR]  5.4  16   9  0.640  3.00  33  33  ...   4
# 3           Logan Webb   27  [SFG]  3.6  13  10  0.565  3.47  33  33  ...   4
# 4         Zack Wheeler   34  [PHI]  6.1  16   7  0.696  2.57  32  32  ...   8
# 5           Aaron Nola   31  [PHI]  3.7  14   8  0.636  3.57  33  33  ...   2
# ..                 ...  ...    ...  ...  ..  ..    ...   ...  ..  ..  ...  ..
# 536  Emmanuel RamÃ­rez   29  [MIA] -0.3   0   1  0.000  6.97  15   0  ...   2
# 537    Erasmo RamÃ­rez   34  [TBR] -0.2   3   0  1.000  4.35  13   0  ...   2
# 538         Ryder Ryan   29  [PIT] -0.2   1   0  1.000  5.66  15   0  ...   0
# 539      Scott Blewett   28  [MIN]  0.8   1   1  0.500  1.77  12   0  ...   0
# 541         River Ryan   25  [LAD]  0.7   1   0  1.000  1.33   4   4  ...   0
#
#       BF   ERA+   FIP   WHIP   H9  HR9  BB9   SO9  SO/BB
# Rk
# 1    803  113.0  3.27  0.887  6.4  1.1  1.6   9.5   5.95
# 2    836  139.0  3.25  1.089  7.7  0.7  2.1   7.9   3.77
# 3    841  111.0  2.95  1.231  8.9  0.5  2.2   7.6   3.44
# 4    787  160.0  3.13  0.955  6.3  0.9  2.3  10.1   4.31
# 5    820  115.0  3.94  1.199  8.5  1.4  2.3   8.9   3.94
# ..   ...    ...   ...    ...  ...  ...  ...   ...    ...
# 536   92   65.0  4.62  1.403  9.1  1.3  3.5   9.1   2.63
# 537   85   93.0  6.46  1.065  5.2  2.2  4.4   6.5   1.50
# 538   93   75.0  4.52  1.452  9.1  0.9  3.9   7.4   1.89
# 539   85  240.0  4.00  1.230  7.5  0.9  3.5   8.0   2.25
# 541   81  296.0  3.36  1.180  6.6  0.4  4.0   8.0   2.00
#
# [535 rows x 34 columns]

# %%
MLB_data = pd.read_csv("data/MLB_Pitchers.csv", encoding = 'latin-1')
MLB_data = (MLB_data.drop(columns = ["Lg", "Awards", "Player-additional"]).query('IP > 20').dropna())
duplicates = MLB_data[MLB_data.duplicated('Rk', keep = False)]
team_dict = dict()
for index, row in duplicates.iterrows():
    if row['Rk'] not in list(team_dict.keys()):
        team_dict[row['Rk']] = [row['Team']]
    else:
        team_dict[row['Rk']].append(row['Team'])
for elem in team_dict:
    del team_dict[elem][0]
team_df = pd.DataFrame(list(team_dict.items()), columns = ['Rk', 'Team'])
MLB_data = MLB_data.groupby('Rk').agg("first").reset_index()
MLB_data['Team'] = MLB_data['Team'].apply(lambda x: [x])
MLB_data.set_index('Rk', inplace = True)
team_df.set_index('Rk', inplace = True)
MLB_data.update(team_df)
MLB_data = MLB_data.reset_index().drop(columns = 'Rk')
Identifiers = MLB_data[['Player', 'Team']]
MLB_data = MLB_data.drop(columns = ['Player', 'Team'])
unique_values = list(set(val for sublist in Identifiers['Team'] for val in sublist))

# %%
Identifiers
# Out:
#                 Player   Team
# 0        Logan Gilbert  [SEA]
# 1            Seth Lugo  [KCR]
# 2           Logan Webb  [SFG]
# 3         Zack Wheeler  [PHI]
# 4           Aaron Nola  [PHI]
# ..                 ...    ...
# 530  Emmanuel RamÃ­rez  [MIA]
# 531    Erasmo RamÃ­rez  [TBR]
# 532         Ryder Ryan  [PIT]
# 533      Scott Blewett  [MIN]
# 534         River Ryan  [LAD]
#
# [535 rows x 2 columns]

# %%
unique_values
# Out:
# ['SEA',
#  'NYY',
#  'SDP',
#  'STL',
#  'NYM',
#  'WSN',
#  'TEX',
#  '2TM',
#  'SFG',
#  'LAA',
#  'HOU',
#  'CIN',
#  'MIL',
#  'CHW',
#  'CHC',
#  'PHI',
#  'OAK',
#  'ATL',
#  'KCR',
#  'COL',
#  'PIT',
#  'TBR',
#  'BOS',
#  'MIN',
#  'CLE',
#  'ARI',
#  'LAD',
#  'BAL',
#  '3TM',
#  'TOR',
#  'DET',
#  'MIA']

# %%
MLB_data
# Out:
#                 Player  Age   Team  WAR   W   L   W-L%   ERA   G  GS  ...  WP  \
# 0        Logan Gilbert   27  [SEA]  2.8   9  12  0.429  3.23  33  33  ...  11
# 1            Seth Lugo   34  [KCR]  5.4  16   9  0.640  3.00  33  33  ...   4
# 2           Logan Webb   27  [SFG]  3.6  13  10  0.565  3.47  33  33  ...   4
# 3         Zack Wheeler   34  [PHI]  6.1  16   7  0.696  2.57  32  32  ...   8
# 4           Aaron Nola   31  [PHI]  3.7  14   8  0.636  3.57  33  33  ...   2
# ..                 ...  ...    ...  ...  ..  ..    ...   ...  ..  ..  ...  ..
# 530  Emmanuel RamÃ­rez   29  [MIA] -0.3   0   1  0.000  6.97  15   0  ...   2
# 531    Erasmo RamÃ­rez   34  [TBR] -0.2   3   0  1.000  4.35  13   0  ...   2
# 532         Ryder Ryan   29  [PIT] -0.2   1   0  1.000  5.66  15   0  ...   0
# 533      Scott Blewett   28  [MIN]  0.8   1   1  0.500  1.77  12   0  ...   0
# 534         River Ryan   25  [LAD]  0.7   1   0  1.000  1.33   4   4  ...   0
#
#       BF   ERA+   FIP   WHIP   H9  HR9  BB9   SO9  SO/BB
# 0    803  113.0  3.27  0.887  6.4  1.1  1.6   9.5   5.95
# 1    836  139.0  3.25  1.089  7.7  0.7  2.1   7.9   3.77
# 2    841  111.0  2.95  1.231  8.9  0.5  2.2   7.6   3.44
# 3    787  160.0  3.13  0.955  6.3  0.9  2.3  10.1   4.31
# 4    820  115.0  3.94  1.199  8.5  1.4  2.3   8.9   3.94
# ..   ...    ...   ...    ...  ...  ...  ...   ...    ...
# 530   92   65.0  4.62  1.403  9.1  1.3  3.5   9.1   2.63
# 531   85   93.0  6.46  1.065  5.2  2.2  4.4   6.5   1.50
# 532   93   75.0  4.52  1.452  9.1  0.9  3.9   7.4   1.89
# 533   85  240.0  4.00  1.230  7.5  0.9  3.5   8.0   2.25
# 534   81  296.0  3.36  1.180  6.6  0.4  4.0   8.0   2.00
#
# [535 rows x 34 columns]

# %%
Identifiers = MLB_data[['Player', 'Team']]
MLB_data = MLB_data.drop(columns = ['Player', 'Team'])

# %%
Identifiers
# Out:
#                 Player   Team
# 0        Logan Gilbert  [SEA]
# 1            Seth Lugo  [KCR]
# 2           Logan Webb  [SFG]
# 3         Zack Wheeler  [PHI]
# 4           Aaron Nola  [PHI]
# ..                 ...    ...
# 530  Emmanuel RamÃ­rez  [MIA]
# 531    Erasmo RamÃ­rez  [TBR]
# 532         Ryder Ryan  [PIT]
# 533      Scott Blewett  [MIN]
# 534         River Ryan  [LAD]
#
# [535 rows x 2 columns]

# %%
Identifiers['Team'].unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 Identifiers['Team'].unique()
#
# File c:\Users\t_cla\anaconda3\Lib\site-packages\pandas\core\series.py:2407, in Series.unique(self)
#    2344 def unique(self) -> ArrayLike:  # pylint: disable=useless-parent-delegation
#    2345     """
#    2346     Return unique values of Series object.
#    2347
#    (...)
#    2405     Categories (3, object): ['a' < 'b' < 'c']
#    2406     """
# -> 2407     return super().unique()
#
# File c:\Users\t_cla\anaconda3\Lib\site-packages\pandas\core\base.py:1025, in IndexOpsMixin.unique(self)
#    1023     result = values.unique()
#    1024 else:
# -> 1025     result = algorithms.unique1d(values)
#    1026 return result
#
# File c:\Users\t_cla\anaconda3\Lib\site-packages\pandas\core\algorithms.py:401, in unique(values)
#     307 def unique(values):
#     308     """
#     309     Return unique values based on a hash table.
#     310
#    (...)
#     399     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     400     """
# --> 401     return unique_with_mask(values)
#
# File c:\Users\t_cla\anaconda3\Lib\site-packages\pandas\core\algorithms.py:440, in unique_with_mask(values, mask)
#     438 table = hashtable(len(values))
#     439 if mask is None:
# --> 440     uniques = table.unique(values)
#     441     uniques = _reconstruct_data(uniques, original.dtype, original)
#     442     return uniques
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7248, in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7195, in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
unique_values = set(val for sublist in Identifiers['Team'] for val in sublist)
unique_values
# Out:
# {'2TM',
#  '3TM',
#  'ARI',
#  'ATL',
#  'BAL',
#  'BOS',
#  'CHC',
#  'CHW',
#  'CIN',
#  'CLE',
#  'COL',
#  'DET',
#  'HOU',
#  'KCR',
#  'LAA',
#  'LAD',
#  'MIA',
#  'MIL',
#  'MIN',
#  'NYM',
#  'NYY',
#  'OAK',
#  'PHI',
#  'PIT',
#  'SDP',
#  'SEA',
#  'SFG',
#  'STL',
#  'TBR',
#  'TEX',
#  'TOR',
#  'WSN'}

# %%
list(unique_values)
# Out:
# ['SEA',
#  'NYY',
#  'SDP',
#  'STL',
#  'NYM',
#  'WSN',
#  'TEX',
#  '2TM',
#  'SFG',
#  'LAA',
#  'HOU',
#  'CIN',
#  'MIL',
#  'CHW',
#  'CHC',
#  'PHI',
#  'OAK',
#  'ATL',
#  'KCR',
#  'COL',
#  'PIT',
#  'TBR',
#  'BOS',
#  'MIN',
#  'CLE',
#  'ARI',
#  'LAD',
#  'BAL',
#  '3TM',
#  'TOR',
#  'DET',
#  'MIA']
